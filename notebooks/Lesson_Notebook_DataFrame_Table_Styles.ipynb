# %% [markdown]
# # Advanced pandas - Going Beyond the Basics
#
# ## DataFrame Table Styles
# ___
#
# ### Table of Contents
# 1. [Import dependencies](#section1)
# 2. [Import dataset](#section2)
# 3. [View Styler object](#section3)
# 4. [Text formatting](#section4)
# 5. [Conditional formatting with built-in styles](#section5)
# 6. [Style customization with CSS](#section6)
# 7. [Export styled tables](#section7)

# %% [markdown]
# ___
# <a id='section1'></a>
# # (1) Import dependencies

# %%
# Install dependencies (if not already done so)
# !pip install pandas==2.0.3
# !pip install numpy==1.23.5
# !pip install seaborn==0.12.2
# !pip install openpyxl==3.1.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Check pandas version (ensure it is pandas v2 and above)
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# ___
# <a id='section2'></a>
# # (2) Import dataset
# - Data Source: https://www.kaggle.com/datasets/datascientistanna/customers-dataset (Database Contents License (DbCL) v1.0)

# %%
# Import and read CSV file
df = pd.read_csv('https://raw.githubusercontent.com/kennethleungty/Educative-Advanced-Pandas/main/data/csv/Customers_Mini.csv')

# Set CustomerID as index
df = df.set_index('CustomerID')

# View DataFrame
df
# Out:
#             Gender  Age  AnnualIncome  SpendingScore Profession  \
# CustomerID
# 1             Male   19         15000             39  Scientist
# 2             Male   21         35000             81   Engineer
# 3           Female   20         86000              6   Engineer
# 4           Female   23         59000             77     Lawyer
# 5           Female   31         38000             40     Artist
# 6           Female   22         58000             76   Engineer
# 7           Female   35         31000              6  Scientist
#
#             WorkExperience  FamilySize
# CustomerID
# 1                        1           4
# 2                        3           3
# 3                        1           1
# 4                        0           2
# 5                        2           6
# 6                        0           2
# 7                        1           3

# %% [markdown]
# ___
# <a id='section3'></a>
# # (3) View Styler object

# %% [markdown]
# We saw earlier in the Introduction section that the `df.style` attribute produces a `Styler` object. We can view it with the code below:

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c02b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c02b7_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_c02b7_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_c02b7_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_c02b7_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_c02b7_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_c02b7_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_c02b7_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c02b7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c02b7_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_c02b7_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_c02b7_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_c02b7_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_c02b7_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_c02b7_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_c02b7_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c02b7_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_c02b7_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_c02b7_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_c02b7_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_c02b7_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_c02b7_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_c02b7_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c02b7_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_c02b7_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_c02b7_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_c02b7_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_c02b7_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_c02b7_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_c02b7_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c02b7_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_c02b7_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_c02b7_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_c02b7_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_c02b7_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_c02b7_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_c02b7_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c02b7_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_c02b7_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_c02b7_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_c02b7_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_c02b7_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_c02b7_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_c02b7_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c02b7_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_c02b7_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_c02b7_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_c02b7_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_c02b7_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_c02b7_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_c02b7_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c02b7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c02b7_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_c02b7_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_c02b7_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_c02b7_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_c02b7_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_c02b7_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_c02b7_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
type(df.style)
# Out:
# pandas.io.formats.style.Styler

# %% [markdown]
# The output above shows that the `Styler` object returns the same DataFrame table, but its data type is no longer the original `pandas.core.frame.DataFrame`, and is instead `pandas.io.formats.style.Styler`

# %% [markdown]
# ___
# <a id='section4'></a>
# # (4) Text formatting
# https://pandas.pydata.org/docs/user_guide/style.html#Formatting-Values

# %% [markdown]
# ## (i) Data

# %% [markdown]
# Let us first explore how to adjust the formatting display of the values in DataFrame cells. To control the display of these values, we can use the `format()` method. It contains different parameters that define the format specification (which are strings that express how the data should be presented). It works by assigning a formatting function (known as `formatter`) to each cell in the DataFrame.
#
# For instance, we can apply a generic formatting on the entire DataFrame to convert floats to having a precision of 3, set the decimal point separator as a comma, and set the thousand separator as a period, as shown below:

# %%
df.style.format(precision=3, thousands='.', decimal=',')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8ab7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8ab7_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_e8ab7_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_e8ab7_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_e8ab7_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_e8ab7_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_e8ab7_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_e8ab7_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8ab7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e8ab7_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_e8ab7_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_e8ab7_row0_col2" class="data row0 col2" >15.000</td>
#       <td id="T_e8ab7_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_e8ab7_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_e8ab7_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e8ab7_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e8ab7_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_e8ab7_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_e8ab7_row1_col2" class="data row1 col2" >35.000</td>
#       <td id="T_e8ab7_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_e8ab7_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_e8ab7_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_e8ab7_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e8ab7_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_e8ab7_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_e8ab7_row2_col2" class="data row2 col2" >86.000</td>
#       <td id="T_e8ab7_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_e8ab7_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_e8ab7_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_e8ab7_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e8ab7_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_e8ab7_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_e8ab7_row3_col2" class="data row3 col2" >59.000</td>
#       <td id="T_e8ab7_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_e8ab7_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_e8ab7_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e8ab7_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e8ab7_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_e8ab7_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_e8ab7_row4_col2" class="data row4 col2" >38.000</td>
#       <td id="T_e8ab7_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_e8ab7_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_e8ab7_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_e8ab7_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e8ab7_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_e8ab7_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_e8ab7_row5_col2" class="data row5 col2" >58.000</td>
#       <td id="T_e8ab7_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_e8ab7_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_e8ab7_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_e8ab7_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8ab7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e8ab7_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_e8ab7_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_e8ab7_row6_col2" class="data row6 col2" >31.000</td>
#       <td id="T_e8ab7_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_e8ab7_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_e8ab7_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_e8ab7_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The output above shows that the formatting of the values in the "AnnualIncome" column has been modified accordingly. It is because the "AnnualIncome" column is the only one with values in the thousands range. However, an important thing to note is that the underlying data type is unchanged, as shown below where "AnnualIncome" continues to have the `int64` data type:

# %%
df.dtypes
# Out:
# Gender            object
# Age                int64
# AnnualIncome       int64
# SpendingScore      int64
# Profession        object
# WorkExperience     int64
# FamilySize         int64
# dtype: object

# %% [markdown]
# The `precision`, `thousands`, and `decimal` parameters are just some examples of the parameters native to the `format()` method. The following information explains the various parameters that we can leverage in `format()`:
#
# - `subset`: Defines the columns to apply the formatting function to.
# - `na_rep`: Sets the representation for missing values. If `None` (default), no special formatting will be applied.
# - `precision`: Floating point precision for the numerical values.
# - `decimal`: Character used as the separator for the decimal points.
# - `thosands`: Character used as the separate for the thousands value. Default value is `None`.
# - `escape`: Defines the method for escaping special characters. Passing `'html'` and `'latex'` will replace the special characters with HTML-safe and LaTeX-safe sequences respectively.
# - `hyperlinks`: Converts hyperlink-like string patterns into clickable links. Passing `'html'` and `'latex'` will set clickable URL hyperlinks and LaTeX href commands respectively.
#
# Besides `precision` (default value is 6) and `decimal` (default character is `.`), the other parameters have a default value of `None`.

# %% [markdown]
# We can also apply a different format specification for each column by providing dictionaries, as seen in the example below:

# %%
df.style.format({
               'WorkExperience': '{:,.2f}', # format as float rounded to 2 decimal places
               'SpendingScore': '{:.1%}',  # format as percentage rounded to 1 decimal place
               'AnnualIncome': '{:,}',    # format with comma as thousand separator
               'Gender': '{}'  # format as string
                })
# Out:
# <style type="text/css">
# </style>
# <table id="T_7be9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7be9b_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_7be9b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_7be9b_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_7be9b_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_7be9b_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_7be9b_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_7be9b_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7be9b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7be9b_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_7be9b_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_7be9b_row0_col2" class="data row0 col2" >15,000</td>
#       <td id="T_7be9b_row0_col3" class="data row0 col3" >3900.0%</td>
#       <td id="T_7be9b_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_7be9b_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_7be9b_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7be9b_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_7be9b_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_7be9b_row1_col2" class="data row1 col2" >35,000</td>
#       <td id="T_7be9b_row1_col3" class="data row1 col3" >8100.0%</td>
#       <td id="T_7be9b_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_7be9b_row1_col5" class="data row1 col5" >3.00</td>
#       <td id="T_7be9b_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7be9b_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_7be9b_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_7be9b_row2_col2" class="data row2 col2" >86,000</td>
#       <td id="T_7be9b_row2_col3" class="data row2 col3" >600.0%</td>
#       <td id="T_7be9b_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_7be9b_row2_col5" class="data row2 col5" >1.00</td>
#       <td id="T_7be9b_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7be9b_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_7be9b_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_7be9b_row3_col2" class="data row3 col2" >59,000</td>
#       <td id="T_7be9b_row3_col3" class="data row3 col3" >7700.0%</td>
#       <td id="T_7be9b_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_7be9b_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_7be9b_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7be9b_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_7be9b_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_7be9b_row4_col2" class="data row4 col2" >38,000</td>
#       <td id="T_7be9b_row4_col3" class="data row4 col3" >4000.0%</td>
#       <td id="T_7be9b_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_7be9b_row4_col5" class="data row4 col5" >2.00</td>
#       <td id="T_7be9b_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7be9b_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_7be9b_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_7be9b_row5_col2" class="data row5 col2" >58,000</td>
#       <td id="T_7be9b_row5_col3" class="data row5 col3" >7600.0%</td>
#       <td id="T_7be9b_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_7be9b_row5_col5" class="data row5 col5" >0.00</td>
#       <td id="T_7be9b_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7be9b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7be9b_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_7be9b_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_7be9b_row6_col2" class="data row6 col2" >31,000</td>
#       <td id="T_7be9b_row6_col3" class="data row6 col3" >600.0%</td>
#       <td id="T_7be9b_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_7be9b_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_7be9b_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The example above shows that each key-value pair of the dictionary corresponds to a column and its respective format specification, which are strings that define how the data should be presented.
#
# Let us look at another example. Suppose we now make introduce some null values into our dataset. We can then perform a different set of formatting as shown below:

# %%
# Generate df with NaN values
total_values = df.size
n_nulls = 5
df_nan = df.copy()
rows = np.random.choice(df_nan.index, n_nulls)
cols = np.random.choice(df_nan.columns, n_nulls)

# Replace chosen locations with NaN
for row, col in zip(rows, cols):
    df_nan.at[row, col] = np.nan

# View output
df_nan
# Out:
#             Gender  Age  AnnualIncome  SpendingScore Profession  \
# CustomerID
# 1             Male   19         15000           39.0  Scientist
# 2             Male   21         35000            NaN        NaN
# 3           Female   20         86000            6.0   Engineer
# 4           Female   23         59000           77.0     Lawyer
# 5           Female   31         38000           40.0     Artist
# 6           Female   22         58000           76.0   Engineer
# 7           Female   35         31000            6.0  Scientist
#
#             WorkExperience  FamilySize
# CustomerID
# 1                      1.0           4
# 2                      3.0           3
# 3                      1.0           1
# 4                      0.0           2
# 5                      NaN           6
# 6                      NaN           2
# 7                      NaN           3

# %%
# Apply formatting
func = lambda s: 'JOB' if isinstance(s, str) else 'NO JOB'

# Perform series of formatting changes
df_nan.style.format({'Age': '{:.1f}', 
                     'Profession': func}, 
                     na_rep='MISSING')
# Out:
# <style type="text/css">
# </style>
# <table id="T_29a7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29a7f_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_29a7f_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_29a7f_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_29a7f_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_29a7f_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_29a7f_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_29a7f_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29a7f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_29a7f_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_29a7f_row0_col1" class="data row0 col1" >19.0</td>
#       <td id="T_29a7f_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_29a7f_row0_col3" class="data row0 col3" >39.000000</td>
#       <td id="T_29a7f_row0_col4" class="data row0 col4" >JOB</td>
#       <td id="T_29a7f_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_29a7f_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_29a7f_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_29a7f_row1_col1" class="data row1 col1" >21.0</td>
#       <td id="T_29a7f_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_29a7f_row1_col3" class="data row1 col3" >MISSING</td>
#       <td id="T_29a7f_row1_col4" class="data row1 col4" >MISSING</td>
#       <td id="T_29a7f_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_29a7f_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_29a7f_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_29a7f_row2_col1" class="data row2 col1" >20.0</td>
#       <td id="T_29a7f_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_29a7f_row2_col3" class="data row2 col3" >6.000000</td>
#       <td id="T_29a7f_row2_col4" class="data row2 col4" >JOB</td>
#       <td id="T_29a7f_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_29a7f_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_29a7f_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_29a7f_row3_col1" class="data row3 col1" >23.0</td>
#       <td id="T_29a7f_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_29a7f_row3_col3" class="data row3 col3" >77.000000</td>
#       <td id="T_29a7f_row3_col4" class="data row3 col4" >JOB</td>
#       <td id="T_29a7f_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_29a7f_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_29a7f_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_29a7f_row4_col1" class="data row4 col1" >31.0</td>
#       <td id="T_29a7f_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_29a7f_row4_col3" class="data row4 col3" >40.000000</td>
#       <td id="T_29a7f_row4_col4" class="data row4 col4" >JOB</td>
#       <td id="T_29a7f_row4_col5" class="data row4 col5" >MISSING</td>
#       <td id="T_29a7f_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_29a7f_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_29a7f_row5_col1" class="data row5 col1" >22.0</td>
#       <td id="T_29a7f_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_29a7f_row5_col3" class="data row5 col3" >76.000000</td>
#       <td id="T_29a7f_row5_col4" class="data row5 col4" >JOB</td>
#       <td id="T_29a7f_row5_col5" class="data row5 col5" >MISSING</td>
#       <td id="T_29a7f_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_29a7f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_29a7f_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_29a7f_row6_col1" class="data row6 col1" >35.0</td>
#       <td id="T_29a7f_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_29a7f_row6_col3" class="data row6 col3" >6.000000</td>
#       <td id="T_29a7f_row6_col4" class="data row6 col4" >JOB</td>
#       <td id="T_29a7f_row6_col5" class="data row6 col5" >MISSING</td>
#       <td id="T_29a7f_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The output above shows that we have performed the following formatting changes:
# - Set values in "Age" column to be displayed as 1 decimal place. The `.1` means we want to round the number to 1 decimal place.
# - Replace non-null values in "Profession" column with the string "JOB" using custom lambda function
# - Replace null values in entire DataFrame with the string "MISSING"
#
# If the code for defining formatting looks familiar, it is because the `pandas` `format()` method is related to Python's string format syntax, where they both use the same underlying mechanics to format the representation of numbers.
#
# For example, the following Python code format using replacement fields surrounded by curly braces {}, where we convert a float into numerical dollar value with 2 decimal places:

# %%
# Convert number into numerical dollar value with 2 decimal places and comma as thousands separator
x = 1012.3456
print('${:,.2f}'.format(x))
# Out:
# $1,012.35

# %% [markdown]
# The same concept is applied when we perform the same conversion for the values in the "AnnualIncome" column, as seen below:

# %%
# Format the annual income column
df.style.format({'AnnualIncome': '${:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_79b5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79b5b_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_79b5b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_79b5b_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_79b5b_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_79b5b_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_79b5b_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_79b5b_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79b5b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_79b5b_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_79b5b_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_79b5b_row0_col2" class="data row0 col2" >$15,000.00</td>
#       <td id="T_79b5b_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_79b5b_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_79b5b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_79b5b_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_79b5b_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_79b5b_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_79b5b_row1_col2" class="data row1 col2" >$35,000.00</td>
#       <td id="T_79b5b_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_79b5b_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_79b5b_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_79b5b_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_79b5b_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_79b5b_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_79b5b_row2_col2" class="data row2 col2" >$86,000.00</td>
#       <td id="T_79b5b_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_79b5b_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_79b5b_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_79b5b_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_79b5b_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_79b5b_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_79b5b_row3_col2" class="data row3 col2" >$59,000.00</td>
#       <td id="T_79b5b_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_79b5b_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_79b5b_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_79b5b_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_79b5b_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_79b5b_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_79b5b_row4_col2" class="data row4 col2" >$38,000.00</td>
#       <td id="T_79b5b_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_79b5b_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_79b5b_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_79b5b_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_79b5b_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_79b5b_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_79b5b_row5_col2" class="data row5 col2" >$58,000.00</td>
#       <td id="T_79b5b_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_79b5b_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_79b5b_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_79b5b_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_79b5b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_79b5b_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_79b5b_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_79b5b_row6_col2" class="data row6 col2" >$31,000.00</td>
#       <td id="T_79b5b_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_79b5b_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_79b5b_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_79b5b_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see from the output that each number in the DataFrame column is displayed with two decimal places, commas as thousand separators, and prefixed by a dollar sign.

# %% [markdown]
# ## (ii) Index
# Besides formatting the data within the DataFrame cells, we have methods to format the text display value of index labels or column headers too. These methods are namely `format_index()` and `relabel_index()`.
#
# For example, we can uppercase all the column headers with `format_index()`, as shown below:

# %%
df.style.format_index(lambda v: str.upper(v), # String uppercase
                        axis=1 # Represents columns (axis=1)
                      )
# Out:
# <style type="text/css">
# </style>
# <table id="T_f74f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f74f7_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_f74f7_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_f74f7_level0_col2" class="col_heading level0 col2" >ANNUALINCOME</th>
#       <th id="T_f74f7_level0_col3" class="col_heading level0 col3" >SPENDINGSCORE</th>
#       <th id="T_f74f7_level0_col4" class="col_heading level0 col4" >PROFESSION</th>
#       <th id="T_f74f7_level0_col5" class="col_heading level0 col5" >WORKEXPERIENCE</th>
#       <th id="T_f74f7_level0_col6" class="col_heading level0 col6" >FAMILYSIZE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f74f7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f74f7_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_f74f7_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_f74f7_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_f74f7_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_f74f7_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_f74f7_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_f74f7_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f74f7_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_f74f7_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_f74f7_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_f74f7_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_f74f7_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_f74f7_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_f74f7_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f74f7_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_f74f7_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_f74f7_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_f74f7_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_f74f7_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_f74f7_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_f74f7_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f74f7_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_f74f7_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_f74f7_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_f74f7_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_f74f7_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_f74f7_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_f74f7_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f74f7_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_f74f7_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_f74f7_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_f74f7_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_f74f7_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_f74f7_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_f74f7_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f74f7_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_f74f7_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_f74f7_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_f74f7_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_f74f7_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_f74f7_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_f74f7_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f74f7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f74f7_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_f74f7_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_f74f7_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_f74f7_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_f74f7_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_f74f7_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_f74f7_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `format_index()` method has parameters similar to `format()`, except that it has additional parameters like `axis` and `level` to determine the specific way these indices are modified.
#
# For renaming of index labels or column headers, we can use the `relabel_index()` method. For instance, the example below shows how we can use it to rename the index labels (which are the customer IDs):

# %%
# Relabel the values in the index (CustomerID)
df.style.relabel_index([f'Customer{i+1}' for i in range(7)], 
                        axis=0 # Represents index (axis=0)
                       )
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b3ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b3ff_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_2b3ff_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_2b3ff_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_2b3ff_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_2b3ff_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_2b3ff_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_2b3ff_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b3ff_level0_row0" class="row_heading level0 row0" >Customer1</th>
#       <td id="T_2b3ff_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_2b3ff_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_2b3ff_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_2b3ff_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_2b3ff_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_2b3ff_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_2b3ff_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row1" class="row_heading level0 row1" >Customer2</th>
#       <td id="T_2b3ff_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_2b3ff_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_2b3ff_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_2b3ff_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_2b3ff_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_2b3ff_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_2b3ff_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row2" class="row_heading level0 row2" >Customer3</th>
#       <td id="T_2b3ff_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_2b3ff_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_2b3ff_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_2b3ff_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_2b3ff_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_2b3ff_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_2b3ff_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row3" class="row_heading level0 row3" >Customer4</th>
#       <td id="T_2b3ff_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_2b3ff_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_2b3ff_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_2b3ff_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_2b3ff_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_2b3ff_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_2b3ff_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row4" class="row_heading level0 row4" >Customer5</th>
#       <td id="T_2b3ff_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_2b3ff_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_2b3ff_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_2b3ff_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_2b3ff_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_2b3ff_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_2b3ff_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row5" class="row_heading level0 row5" >Customer6</th>
#       <td id="T_2b3ff_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_2b3ff_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_2b3ff_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_2b3ff_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_2b3ff_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_2b3ff_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_2b3ff_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2b3ff_level0_row6" class="row_heading level0 row6" >Customer7</th>
#       <td id="T_2b3ff_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_2b3ff_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_2b3ff_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_2b3ff_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_2b3ff_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_2b3ff_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_2b3ff_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## (iii) Hide

# %% [markdown]
# We can use the `hide()` method to hide certain columns, the index and/or column headers, or index names.
#
# The index can be hidden from rendering by calling `hide()` without any arguments, which might be useful if your index is integer based. Similarly column headers can be hidden by calling `hide(axis="columns")` without any other arguments.
#
# For example, we can hide the "Age" and "Gender" columns from being displayed, as shown below:

# %%
# Hide Age and Gender columns
df.style.hide(subset=['Age', 'Gender'],
                      axis='columns' # We can also use axis=1 
                      )
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea60e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea60e_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_ea60e_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_ea60e_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_ea60e_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_ea60e_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea60e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ea60e_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_ea60e_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_ea60e_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_ea60e_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ea60e_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ea60e_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_ea60e_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_ea60e_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_ea60e_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_ea60e_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ea60e_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_ea60e_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_ea60e_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_ea60e_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ea60e_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ea60e_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_ea60e_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_ea60e_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_ea60e_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_ea60e_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ea60e_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_ea60e_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_ea60e_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_ea60e_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_ea60e_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ea60e_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_ea60e_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_ea60e_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_ea60e_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_ea60e_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea60e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ea60e_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_ea60e_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_ea60e_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_ea60e_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_ea60e_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can even chain this `hide()` method with the methods we learned earlier, such as `relabel_index()`. For example, we can first hide the "Age" and "Gender columns, before renaming the rest, as demonstrated below:

# %%
# Chaining of methods for styling
df.style.hide(['Age', 'Gender'], axis=1)\
        .relabel_index(['A', 'B', 'C', 'D', 'E'], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e52ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e52ed_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_e52ed_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_e52ed_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_e52ed_level0_col5" class="col_heading level0 col5" >D</th>
#       <th id="T_e52ed_level0_col6" class="col_heading level0 col6" >E</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e52ed_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e52ed_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_e52ed_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_e52ed_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_e52ed_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e52ed_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e52ed_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_e52ed_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_e52ed_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_e52ed_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_e52ed_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e52ed_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_e52ed_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_e52ed_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_e52ed_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_e52ed_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e52ed_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_e52ed_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_e52ed_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_e52ed_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e52ed_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e52ed_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_e52ed_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_e52ed_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_e52ed_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_e52ed_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e52ed_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_e52ed_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_e52ed_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_e52ed_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_e52ed_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e52ed_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e52ed_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_e52ed_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_e52ed_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_e52ed_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_e52ed_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## (iv) Concatenate

# %% [markdown]
# We can also use the `concat()` method to append another `Styler` object for combining output into a single table. Two or more `Styler` objects can be concatenated together provided they share the same columns.
#
# The purpose of this method is to extend existing styled DataFrame with other metrics that may be useful but may not conform to the original's structure. It could be for common use cases such as  adding a sub total row, or displaying metrics such as means, variance or counts.
#
# Suppose we first subset the original DataFrame into only the numerical columns (i.e., "Age", "AnnualIncome", "SpendingScore", "WorkExperience", and "FamilySize". With that, we then generate the mean value for each column as shown below:

# %%
# Subset into numerical columns only
df_subset = df[["Age", "AnnualIncome", "SpendingScore", "WorkExperience", "FamilySize"]]

# Obtain mean value for each numerical column with agg() method
df_mean = df_subset.agg('mean').to_frame(name='Mean').T

# View output
df_mean
# Out:
#             Age  AnnualIncome  SpendingScore  WorkExperience  FamilySize
# Mean  24.428571       46000.0      46.428571        1.142857         3.0

# %% [markdown]
# We can then concatenate the `Styler` object version of both DataFrames (the original DataFrame and the DataFrame with summary statistics we generated above):

# %%
# Subset to numerical columns
df_subset = df[["Age", "AnnualIncome", "SpendingScore", "WorkExperience", "FamilySize"]]

# Concatenate Styler objects (obtained with .style) of DataFrames
df_subset.style.concat(df_mean.style)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6865c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6865c_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_6865c_level0_col1" class="col_heading level0 col1" >AnnualIncome</th>
#       <th id="T_6865c_level0_col2" class="col_heading level0 col2" >SpendingScore</th>
#       <th id="T_6865c_level0_col3" class="col_heading level0 col3" >WorkExperience</th>
#       <th id="T_6865c_level0_col4" class="col_heading level0 col4" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6865c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6865c_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_6865c_row0_col1" class="data row0 col1" >15000</td>
#       <td id="T_6865c_row0_col2" class="data row0 col2" >39</td>
#       <td id="T_6865c_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_6865c_row0_col4" class="data row0 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6865c_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_6865c_row1_col1" class="data row1 col1" >35000</td>
#       <td id="T_6865c_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_6865c_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_6865c_row1_col4" class="data row1 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6865c_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_6865c_row2_col1" class="data row2 col1" >86000</td>
#       <td id="T_6865c_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_6865c_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_6865c_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6865c_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_6865c_row3_col1" class="data row3 col1" >59000</td>
#       <td id="T_6865c_row3_col2" class="data row3 col2" >77</td>
#       <td id="T_6865c_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_6865c_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6865c_row4_col0" class="data row4 col0" >31</td>
#       <td id="T_6865c_row4_col1" class="data row4 col1" >38000</td>
#       <td id="T_6865c_row4_col2" class="data row4 col2" >40</td>
#       <td id="T_6865c_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_6865c_row4_col4" class="data row4 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6865c_row5_col0" class="data row5 col0" >22</td>
#       <td id="T_6865c_row5_col1" class="data row5 col1" >58000</td>
#       <td id="T_6865c_row5_col2" class="data row5 col2" >76</td>
#       <td id="T_6865c_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_6865c_row5_col4" class="data row5 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6865c_row6_col0" class="data row6 col0" >35</td>
#       <td id="T_6865c_row6_col1" class="data row6 col1" >31000</td>
#       <td id="T_6865c_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_6865c_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_6865c_row6_col4" class="data row6 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6865c_level0_foot0_row0" class="foot0_row_heading level0 foot0_row0" >Mean</th>
#       <td id="T_6865c_foot0_row0_col0" class="foot0_data foot0_row0 col0" >24.428571</td>
#       <td id="T_6865c_foot0_row0_col1" class="foot0_data foot0_row0 col1" >46000.000000</td>
#       <td id="T_6865c_foot0_row0_col2" class="foot0_data foot0_row0 col2" >46.428571</td>
#       <td id="T_6865c_foot0_row0_col3" class="foot0_data foot0_row0 col3" >1.142857</td>
#       <td id="T_6865c_foot0_row0_col4" class="foot0_data foot0_row0 col4" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The output shows how we have performed concatenation such that summary statistics has been easily appended to the original DataFrame as part of the output display.
#
# > **Note**: The other Styler object to be appended in the concatenation must have the same columns as the original.
#
# We can also perform independent formatting on each `Styler` object before the concatenation, as shown below:

# %%
# Independently format Styler objects and then concatenate
df_subset.style.format({'AnnualIncome': '${:,.2f}'})\
               .concat(df_mean.style.format('{:.1f}') # 1 decimal place
                )
# Out:
# <style type="text/css">
# </style>
# <table id="T_faa24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faa24_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_faa24_level0_col1" class="col_heading level0 col1" >AnnualIncome</th>
#       <th id="T_faa24_level0_col2" class="col_heading level0 col2" >SpendingScore</th>
#       <th id="T_faa24_level0_col3" class="col_heading level0 col3" >WorkExperience</th>
#       <th id="T_faa24_level0_col4" class="col_heading level0 col4" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faa24_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_faa24_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_faa24_row0_col1" class="data row0 col1" >$15,000.00</td>
#       <td id="T_faa24_row0_col2" class="data row0 col2" >39</td>
#       <td id="T_faa24_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_faa24_row0_col4" class="data row0 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_faa24_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_faa24_row1_col1" class="data row1 col1" >$35,000.00</td>
#       <td id="T_faa24_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_faa24_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_faa24_row1_col4" class="data row1 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_faa24_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_faa24_row2_col1" class="data row2 col1" >$86,000.00</td>
#       <td id="T_faa24_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_faa24_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_faa24_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_faa24_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_faa24_row3_col1" class="data row3 col1" >$59,000.00</td>
#       <td id="T_faa24_row3_col2" class="data row3 col2" >77</td>
#       <td id="T_faa24_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_faa24_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_faa24_row4_col0" class="data row4 col0" >31</td>
#       <td id="T_faa24_row4_col1" class="data row4 col1" >$38,000.00</td>
#       <td id="T_faa24_row4_col2" class="data row4 col2" >40</td>
#       <td id="T_faa24_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_faa24_row4_col4" class="data row4 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_faa24_row5_col0" class="data row5 col0" >22</td>
#       <td id="T_faa24_row5_col1" class="data row5 col1" >$58,000.00</td>
#       <td id="T_faa24_row5_col2" class="data row5 col2" >76</td>
#       <td id="T_faa24_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_faa24_row5_col4" class="data row5 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_faa24_row6_col0" class="data row6 col0" >35</td>
#       <td id="T_faa24_row6_col1" class="data row6 col1" >$31,000.00</td>
#       <td id="T_faa24_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_faa24_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_faa24_row6_col4" class="data row6 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_faa24_level0_foot0_row0" class="foot0_row_heading level0 foot0_row0" >Mean</th>
#       <td id="T_faa24_foot0_row0_col0" class="foot0_data foot0_row0 col0" >24.4</td>
#       <td id="T_faa24_foot0_row0_col1" class="foot0_data foot0_row0 col1" >46000.0</td>
#       <td id="T_faa24_foot0_row0_col2" class="foot0_data foot0_row0 col2" >46.4</td>
#       <td id="T_faa24_foot0_row0_col3" class="foot0_data foot0_row0 col3" >1.1</td>
#       <td id="T_faa24_foot0_row0_col4" class="foot0_data foot0_row0 col4" >3.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ___
# <a id='section5'></a>
# # (5) Conditional formatting with built-in styles

# %% [markdown]
# Having focused on styling the text and numerical values in the DataFrame cells earlier, let us now take a look at how we can incorporate colors and highlights into the table styling.
#
# In particular, we will start by looking at several styling functions that are common enough such that they have been built into the `Styler` objects. It means that we can easily utilize them without requiring to write custom functions for those specific styles.
#
# These built-in styles tend to be what we call **conditional formatting**, as their visual display is dependent on the values in the tables. Let us explore how each of these built-in styles works:

# %% [markdown]
# ## Null

# %% [markdown]
# The `highlight_null()` function allows us to easily highlight and identify missing and null data in the DataFrame, as shown below:

# %%
# Generate df with NaN values
total_values = df.size
n_nulls = 5
df_nan = df.copy()
rows = np.random.choice(df_nan.index, n_nulls)
cols = np.random.choice(df_nan.columns, n_nulls)

# Replace chosen locations with NaN
for row, col in zip(rows, cols):
    df_nan.at[row, col] = np.nan

# %%
# Highlight null values with defined color
df_nan.style.highlight_null(color='yellow')
# Out:
# <style type="text/css">
# #T_90d27_row0_col5, #T_90d27_row1_col4, #T_90d27_row2_col2, #T_90d27_row5_col5, #T_90d27_row6_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_90d27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90d27_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_90d27_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_90d27_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_90d27_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_90d27_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_90d27_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_90d27_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90d27_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_90d27_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_90d27_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_90d27_row0_col2" class="data row0 col2" >15000.000000</td>
#       <td id="T_90d27_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_90d27_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_90d27_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_90d27_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_90d27_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_90d27_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_90d27_row1_col2" class="data row1 col2" >35000.000000</td>
#       <td id="T_90d27_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_90d27_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_90d27_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_90d27_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_90d27_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_90d27_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_90d27_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_90d27_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_90d27_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_90d27_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_90d27_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_90d27_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_90d27_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_90d27_row3_col2" class="data row3 col2" >59000.000000</td>
#       <td id="T_90d27_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_90d27_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_90d27_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_90d27_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_90d27_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_90d27_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_90d27_row4_col2" class="data row4 col2" >38000.000000</td>
#       <td id="T_90d27_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_90d27_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_90d27_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_90d27_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_90d27_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_90d27_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_90d27_row5_col2" class="data row5 col2" >58000.000000</td>
#       <td id="T_90d27_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_90d27_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_90d27_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_90d27_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_90d27_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_90d27_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_90d27_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_90d27_row6_col2" class="data row6 col2" >31000.000000</td>
#       <td id="T_90d27_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_90d27_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_90d27_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_90d27_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Minimum and maximum

# %% [markdown]
# We can use `highlight_min()` and `highlight_max()` to identifying extremities in numerical data, as demonstrated below:

# %%
# Highlight minimum values with defined color
df.style.highlight_min(color='orange')
# Out:
# <style type="text/css">
# #T_f09d4_row0_col1, #T_f09d4_row0_col2, #T_f09d4_row2_col0, #T_f09d4_row2_col3, #T_f09d4_row2_col6, #T_f09d4_row3_col0, #T_f09d4_row3_col5, #T_f09d4_row4_col0, #T_f09d4_row4_col4, #T_f09d4_row5_col0, #T_f09d4_row5_col5, #T_f09d4_row6_col0, #T_f09d4_row6_col3 {
#   background-color: orange;
# }
# </style>
# <table id="T_f09d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f09d4_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_f09d4_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_f09d4_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_f09d4_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_f09d4_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_f09d4_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_f09d4_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f09d4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f09d4_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_f09d4_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_f09d4_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_f09d4_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_f09d4_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_f09d4_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_f09d4_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f09d4_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_f09d4_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_f09d4_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_f09d4_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_f09d4_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_f09d4_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_f09d4_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f09d4_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_f09d4_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_f09d4_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_f09d4_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_f09d4_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_f09d4_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_f09d4_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f09d4_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_f09d4_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_f09d4_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_f09d4_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_f09d4_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_f09d4_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_f09d4_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f09d4_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_f09d4_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_f09d4_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_f09d4_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_f09d4_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_f09d4_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_f09d4_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f09d4_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_f09d4_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_f09d4_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_f09d4_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_f09d4_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_f09d4_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_f09d4_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f09d4_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f09d4_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_f09d4_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_f09d4_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_f09d4_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_f09d4_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_f09d4_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_f09d4_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Highlight maximum values with defined color
df.style.highlight_max(color='green')
# Out:
# <style type="text/css">
# #T_ffb24_row0_col0, #T_ffb24_row0_col4, #T_ffb24_row1_col0, #T_ffb24_row1_col3, #T_ffb24_row1_col5, #T_ffb24_row2_col2, #T_ffb24_row4_col6, #T_ffb24_row6_col1, #T_ffb24_row6_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_ffb24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffb24_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_ffb24_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_ffb24_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_ffb24_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_ffb24_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_ffb24_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_ffb24_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffb24_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ffb24_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_ffb24_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_ffb24_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_ffb24_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_ffb24_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_ffb24_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ffb24_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ffb24_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_ffb24_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_ffb24_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_ffb24_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_ffb24_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_ffb24_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_ffb24_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ffb24_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_ffb24_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_ffb24_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_ffb24_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_ffb24_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_ffb24_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ffb24_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ffb24_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_ffb24_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_ffb24_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_ffb24_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_ffb24_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_ffb24_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_ffb24_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ffb24_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_ffb24_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_ffb24_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_ffb24_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_ffb24_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_ffb24_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_ffb24_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ffb24_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_ffb24_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_ffb24_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_ffb24_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_ffb24_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_ffb24_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_ffb24_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ffb24_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ffb24_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_ffb24_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_ffb24_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_ffb24_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_ffb24_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_ffb24_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_ffb24_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# An interesting point to note is that these methods also apply to string values, where strings closest to the start (for minimum) or the end (for maximum) of the alphabet are highlighted.
#
# As described earlier, the styling of these tables involves CSS. As such, here is an example where we provide more detailed specifications on how the output should be displayed. In particular, we leverage the `props` parameter to set the CSS properties to use for highlighting.

# %%
# Highlight maximum values with custom CSS properties
df.style.highlight_max(props='color:white; font-weight:bold; \
                              background-color:blue;')
# Out:
# <style type="text/css">
# #T_e4789_row0_col0, #T_e4789_row0_col4, #T_e4789_row1_col0, #T_e4789_row1_col3, #T_e4789_row1_col5, #T_e4789_row2_col2, #T_e4789_row4_col6, #T_e4789_row6_col1, #T_e4789_row6_col4 {
#   color: white;
#   font-weight: bold;
#   background-color: blue;
# }
# </style>
# <table id="T_e4789">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4789_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_e4789_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_e4789_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_e4789_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_e4789_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_e4789_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_e4789_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4789_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e4789_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_e4789_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_e4789_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_e4789_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_e4789_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_e4789_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e4789_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e4789_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_e4789_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_e4789_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_e4789_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_e4789_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_e4789_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_e4789_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e4789_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_e4789_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_e4789_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_e4789_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_e4789_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_e4789_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_e4789_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e4789_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_e4789_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_e4789_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_e4789_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_e4789_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_e4789_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e4789_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e4789_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_e4789_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_e4789_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_e4789_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_e4789_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_e4789_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_e4789_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e4789_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_e4789_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_e4789_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_e4789_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_e4789_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_e4789_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_e4789_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e4789_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e4789_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_e4789_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_e4789_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_e4789_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_e4789_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_e4789_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_e4789_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Note**: When values are passed into `props`, the `color` parameter will not be used.

# %% [markdown]
# ## Quantiles

# %% [markdown]
# `highlight_quantile()` is useful for detecting the highest or lowest percentile values based on our specifications. It only works on numerical values, so we need to define the subset of numerical columns to operate on.

# %%
# Set numerical columns
numerical_cols = ['Age', 'AnnualIncome', 'SpendingScore', 'WorkExperience', 'FamilySize']

# Highlight values belonging to 75th quantile and above
df.style.highlight_quantile(subset=numerical_cols, # Operate only on numerical columns
                                   q_left=0.75, 
                                   props='color:white; background-color:brown;')
# Out:
# <style type="text/css">
# #T_96a1e_row0_col6, #T_96a1e_row1_col3, #T_96a1e_row1_col5, #T_96a1e_row2_col2, #T_96a1e_row3_col2, #T_96a1e_row3_col3, #T_96a1e_row4_col1, #T_96a1e_row4_col5, #T_96a1e_row4_col6, #T_96a1e_row6_col1 {
#   color: white;
#   background-color: brown;
# }
# </style>
# <table id="T_96a1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96a1e_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_96a1e_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_96a1e_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_96a1e_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_96a1e_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_96a1e_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_96a1e_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96a1e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_96a1e_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_96a1e_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_96a1e_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_96a1e_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_96a1e_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_96a1e_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_96a1e_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_96a1e_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_96a1e_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_96a1e_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_96a1e_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_96a1e_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_96a1e_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_96a1e_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_96a1e_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_96a1e_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_96a1e_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_96a1e_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_96a1e_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_96a1e_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_96a1e_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_96a1e_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_96a1e_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_96a1e_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_96a1e_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_96a1e_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_96a1e_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_96a1e_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_96a1e_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_96a1e_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_96a1e_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_96a1e_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_96a1e_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_96a1e_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_96a1e_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_96a1e_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_96a1e_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_96a1e_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_96a1e_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_96a1e_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_96a1e_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_96a1e_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_96a1e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_96a1e_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_96a1e_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_96a1e_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_96a1e_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_96a1e_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_96a1e_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_96a1e_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Between
# `highlight_between()` is useful for detecting values within a specified range.  It can take ranges of values as a means to specify the numerical limits for each column, as shown below:

# %%
# Set numerical columns
numerical_cols = ['Age', 'AnnualIncome', 'SpendingScore', 'WorkExperience', 'FamilySize']

# Define left (aka minimum) limits (each limit value corresponds to column name in index)
left = pd.Series([25, 40000, 50, 2, 3], 
                 index=numerical_cols)

# Highlight based on values within the ranges set for each column
df.style.highlight_between(subset=numerical_cols, # Limit to numerical columns
                                  left=left, 
                                  right=1000, # Set blanket right limit of 1000
                                  axis=1, # Define columns as axis
                                  color='pink')
# Out:
# <style type="text/css">
# #T_c2a8c_row0_col6, #T_c2a8c_row1_col3, #T_c2a8c_row1_col5, #T_c2a8c_row1_col6, #T_c2a8c_row3_col3, #T_c2a8c_row4_col1, #T_c2a8c_row4_col5, #T_c2a8c_row4_col6, #T_c2a8c_row5_col3, #T_c2a8c_row6_col1, #T_c2a8c_row6_col6 {
#   background-color: pink;
# }
# </style>
# <table id="T_c2a8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2a8c_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_c2a8c_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_c2a8c_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_c2a8c_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_c2a8c_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_c2a8c_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_c2a8c_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2a8c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c2a8c_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_c2a8c_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_c2a8c_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_c2a8c_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_c2a8c_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_c2a8c_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_c2a8c_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c2a8c_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_c2a8c_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_c2a8c_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_c2a8c_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_c2a8c_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_c2a8c_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_c2a8c_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c2a8c_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_c2a8c_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_c2a8c_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_c2a8c_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_c2a8c_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_c2a8c_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_c2a8c_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c2a8c_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_c2a8c_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_c2a8c_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_c2a8c_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_c2a8c_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_c2a8c_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_c2a8c_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c2a8c_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_c2a8c_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_c2a8c_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_c2a8c_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_c2a8c_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_c2a8c_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_c2a8c_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c2a8c_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_c2a8c_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_c2a8c_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_c2a8c_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_c2a8c_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_c2a8c_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_c2a8c_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c2a8c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c2a8c_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_c2a8c_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_c2a8c_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_c2a8c_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_c2a8c_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_c2a8c_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_c2a8c_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Gradients

# %% [markdown]
# Besides providing solid colors, we can apply color gradients based on the numerical scale of the values. In particular, we can do either do background gradients (changes cell background color) or text gradients (changes text color), as shown below. We will also be using `seaborn` color palettes for generating visually appealing colormaps, which we will pass into the `cmap` parameter:

# %%
# Set color palette
color_map = sns.color_palette('mako', as_cmap=True)

# Generate background gradients
df.style.background_gradient(cmap=color_map)
# Out:
# <style type="text/css">
# #T_2a98b_row0_col1, #T_2a98b_row0_col2, #T_2a98b_row2_col3, #T_2a98b_row2_col6, #T_2a98b_row3_col5, #T_2a98b_row5_col5, #T_2a98b_row6_col3 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_2a98b_row0_col3 {
#   background-color: #36699f;
#   color: #f1f1f1;
# }
# #T_2a98b_row0_col5, #T_2a98b_row2_col5, #T_2a98b_row6_col5 {
#   background-color: #40498e;
#   color: #f1f1f1;
# }
# #T_2a98b_row0_col6 {
#   background-color: #3497a9;
#   color: #f1f1f1;
# }
# #T_2a98b_row1_col1 {
#   background-color: #2b1c35;
#   color: #f1f1f1;
# }
# #T_2a98b_row1_col2 {
#   background-color: #403c79;
#   color: #f1f1f1;
# }
# #T_2a98b_row1_col3, #T_2a98b_row1_col5, #T_2a98b_row2_col2, #T_2a98b_row4_col6, #T_2a98b_row6_col1 {
#   background-color: #def5e5;
#   color: #000000;
# }
# #T_2a98b_row1_col6, #T_2a98b_row6_col6 {
#   background-color: #395d9c;
#   color: #f1f1f1;
# }
# #T_2a98b_row2_col1 {
#   background-color: #1c101c;
#   color: #f1f1f1;
# }
# #T_2a98b_row3_col1 {
#   background-color: #3e356b;
#   color: #f1f1f1;
# }
# #T_2a98b_row3_col2 {
#   background-color: #359caa;
#   color: #f1f1f1;
# }
# #T_2a98b_row3_col3 {
#   background-color: #c4eacf;
#   color: #000000;
# }
# #T_2a98b_row3_col6, #T_2a98b_row5_col6 {
#   background-color: #382a54;
#   color: #f1f1f1;
# }
# #T_2a98b_row4_col1 {
#   background-color: #4bc2ad;
#   color: #000000;
# }
# #T_2a98b_row4_col2 {
#   background-color: #40468a;
#   color: #f1f1f1;
# }
# #T_2a98b_row4_col3 {
#   background-color: #366da0;
#   color: #f1f1f1;
# }
# #T_2a98b_row4_col5 {
#   background-color: #38aaac;
#   color: #f1f1f1;
# }
# #T_2a98b_row5_col1 {
#   background-color: #37284f;
#   color: #f1f1f1;
# }
# #T_2a98b_row5_col2 {
#   background-color: #3499aa;
#   color: #f1f1f1;
# }
# #T_2a98b_row5_col3 {
#   background-color: #bbe7c8;
#   color: #000000;
# }
# #T_2a98b_row6_col2 {
#   background-color: #3b2f5f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2a98b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a98b_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_2a98b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_2a98b_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_2a98b_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_2a98b_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_2a98b_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_2a98b_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a98b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2a98b_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_2a98b_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_2a98b_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_2a98b_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_2a98b_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_2a98b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_2a98b_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2a98b_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_2a98b_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_2a98b_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_2a98b_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_2a98b_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_2a98b_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_2a98b_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2a98b_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_2a98b_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_2a98b_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_2a98b_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_2a98b_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_2a98b_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_2a98b_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2a98b_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_2a98b_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_2a98b_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_2a98b_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_2a98b_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_2a98b_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_2a98b_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2a98b_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_2a98b_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_2a98b_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_2a98b_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_2a98b_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_2a98b_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_2a98b_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2a98b_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_2a98b_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_2a98b_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_2a98b_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_2a98b_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_2a98b_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_2a98b_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2a98b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2a98b_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_2a98b_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_2a98b_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_2a98b_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_2a98b_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_2a98b_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_2a98b_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can repeat the above gradient coloring but this time using `text_gradient()` for just the text alone:

# %%
# Set color palette
color_map = sns.color_palette('magma', as_cmap=True)

# Generate text gradients
df.style.text_gradient(cmap=color_map)
# Out:
# <style type="text/css">
# #T_debc2_row0_col1, #T_debc2_row0_col2, #T_debc2_row2_col3, #T_debc2_row2_col6, #T_debc2_row3_col5, #T_debc2_row5_col5, #T_debc2_row6_col3 {
#   color: #000004;
# }
# #T_debc2_row0_col3 {
#   color: #9c2e7f;
# }
# #T_debc2_row0_col5, #T_debc2_row2_col5, #T_debc2_row6_col5 {
#   color: #721f81;
# }
# #T_debc2_row0_col6 {
#   color: #de4968;
# }
# #T_debc2_row1_col1 {
#   color: #1d1147;
# }
# #T_debc2_row1_col2 {
#   color: #5d177f;
# }
# #T_debc2_row1_col3, #T_debc2_row1_col5, #T_debc2_row2_col2, #T_debc2_row4_col6, #T_debc2_row6_col1 {
#   color: #fcfdbf;
# }
# #T_debc2_row1_col6, #T_debc2_row6_col6 {
#   color: #8c2981;
# }
# #T_debc2_row2_col1 {
#   color: #0a0822;
# }
# #T_debc2_row3_col1 {
#   color: #51127c;
# }
# #T_debc2_row3_col2 {
#   color: #e44f64;
# }
# #T_debc2_row3_col3 {
#   color: #fde5a7;
# }
# #T_debc2_row3_col6, #T_debc2_row5_col6 {
#   color: #3b0f70;
# }
# #T_debc2_row4_col1 {
#   color: #fc8961;
# }
# #T_debc2_row4_col2 {
#   color: #6d1d81;
# }
# #T_debc2_row4_col3 {
#   color: #a3307e;
# }
# #T_debc2_row4_col5 {
#   color: #f1605d;
# }
# #T_debc2_row5_col1 {
#   color: #36106b;
# }
# #T_debc2_row5_col2 {
#   color: #e04c67;
# }
# #T_debc2_row5_col3 {
#   color: #fddea0;
# }
# #T_debc2_row6_col2 {
#   color: #451077;
# }
# </style>
# <table id="T_debc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_debc2_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_debc2_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_debc2_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_debc2_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_debc2_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_debc2_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_debc2_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_debc2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_debc2_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_debc2_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_debc2_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_debc2_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_debc2_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_debc2_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_debc2_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_debc2_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_debc2_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_debc2_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_debc2_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_debc2_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_debc2_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_debc2_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_debc2_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_debc2_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_debc2_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_debc2_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_debc2_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_debc2_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_debc2_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_debc2_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_debc2_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_debc2_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_debc2_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_debc2_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_debc2_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_debc2_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_debc2_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_debc2_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_debc2_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_debc2_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_debc2_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_debc2_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_debc2_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_debc2_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_debc2_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_debc2_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_debc2_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_debc2_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_debc2_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_debc2_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_debc2_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_debc2_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_debc2_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_debc2_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_debc2_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_debc2_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_debc2_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_debc2_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice that even though we did not specify any subset columns, the non-numerical values for both gradient methods were automatically left unhighlighted.
#
# > **Note**: The `cmap` parameter cannot be used together with the `color` parameter.

# %% [markdown]
# There are three other parameters that are definitely worth a mention:
# - `vmin`: Minimum value for color scaling. Define the lower limit of the data range that will be mapped to the lower end of the color map. Any data values less than `vmin` would be assigned the color that corresponds to this lower limit.
# - `vmax`: Corresponding to `vmin`, this parameter represents the maximum value for color scaling. It defines the upper limit of the data range that will be mapped to the upper end of the color map. Any data values greater than `vmax` would be assigned the color that corresponds to this upper limit.
# - `gmap`: Gradient map (array-like object) for determining the text colors.
#
# For instance, the following code example demonstrates how these three parameters can be used together in `background_gradient()`, where the gradient settings are based on the "FamilySize" column:

# %%
# Set color palette (light sequential gradient)
color_map = sns.color_palette('flare', as_cmap=True)

# Generate background gradients (focus on FamilySize column)
df.style.background_gradient(cmap=color_map,
                            vmin=2,
                            vmax=10,
                            gmap=df['FamilySize'] # Gradient of background based on FamilySize column
                            )
# Out:
# <style type="text/css">
# #T_25a55_row0_col0, #T_25a55_row0_col1, #T_25a55_row0_col2, #T_25a55_row0_col3, #T_25a55_row0_col4, #T_25a55_row0_col5, #T_25a55_row0_col6 {
#   background-color: #e5715e;
#   color: #f1f1f1;
# }
# #T_25a55_row1_col0, #T_25a55_row1_col1, #T_25a55_row1_col2, #T_25a55_row1_col3, #T_25a55_row1_col4, #T_25a55_row1_col5, #T_25a55_row1_col6, #T_25a55_row6_col0, #T_25a55_row6_col1, #T_25a55_row6_col2, #T_25a55_row6_col3, #T_25a55_row6_col4, #T_25a55_row6_col5, #T_25a55_row6_col6 {
#   background-color: #ea916e;
#   color: #f1f1f1;
# }
# #T_25a55_row2_col0, #T_25a55_row2_col1, #T_25a55_row2_col2, #T_25a55_row2_col3, #T_25a55_row2_col4, #T_25a55_row2_col5, #T_25a55_row2_col6, #T_25a55_row3_col0, #T_25a55_row3_col1, #T_25a55_row3_col2, #T_25a55_row3_col3, #T_25a55_row3_col4, #T_25a55_row3_col5, #T_25a55_row3_col6, #T_25a55_row5_col0, #T_25a55_row5_col1, #T_25a55_row5_col2, #T_25a55_row5_col3, #T_25a55_row5_col4, #T_25a55_row5_col5, #T_25a55_row5_col6 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_25a55_row4_col0, #T_25a55_row4_col1, #T_25a55_row4_col2, #T_25a55_row4_col3, #T_25a55_row4_col4, #T_25a55_row4_col5, #T_25a55_row4_col6 {
#   background-color: #c14168;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_25a55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25a55_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_25a55_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_25a55_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_25a55_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_25a55_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_25a55_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_25a55_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25a55_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_25a55_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_25a55_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_25a55_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_25a55_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_25a55_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_25a55_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_25a55_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_25a55_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_25a55_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_25a55_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_25a55_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_25a55_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_25a55_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_25a55_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_25a55_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_25a55_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_25a55_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_25a55_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_25a55_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_25a55_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_25a55_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_25a55_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_25a55_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_25a55_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_25a55_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_25a55_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_25a55_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_25a55_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_25a55_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_25a55_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_25a55_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_25a55_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_25a55_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_25a55_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_25a55_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_25a55_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_25a55_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_25a55_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_25a55_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_25a55_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_25a55_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_25a55_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_25a55_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_25a55_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_25a55_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_25a55_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_25a55_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_25a55_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_25a55_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_25a55_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The "flare" cmap color scheme is shown below:

# %%
sns.color_palette("flare", as_cmap=True)

# %% [markdown]
# ## Bar
# The built-in `bar` style is useful for displaying mini-charts within cell backgrounds of the DataFrame.

# %%
# Generate mini bar charts
df.style.bar(color='lightblue')
# Out:
# <style type="text/css">
# #T_91803_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 54.3%, transparent 54.3%);
# }
# #T_91803_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 17.4%, transparent 17.4%);
# }
# #T_91803_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 48.1%, transparent 48.1%);
# }
# #T_91803_row0_col5, #T_91803_row2_col5, #T_91803_row3_col6, #T_91803_row5_col6, #T_91803_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 33.3%, transparent 33.3%);
# }
# #T_91803_row0_col6, #T_91803_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 66.7%, transparent 66.7%);
# }
# #T_91803_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 60.0%, transparent 60.0%);
# }
# #T_91803_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 40.7%, transparent 40.7%);
# }
# #T_91803_row1_col3, #T_91803_row1_col5, #T_91803_row2_col2, #T_91803_row4_col6, #T_91803_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_91803_row1_col6, #T_91803_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 50.0%, transparent 50.0%);
# }
# #T_91803_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 57.1%, transparent 57.1%);
# }
# #T_91803_row2_col3, #T_91803_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.4%, transparent 7.4%);
# }
# #T_91803_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 16.7%, transparent 16.7%);
# }
# #T_91803_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 65.7%, transparent 65.7%);
# }
# #T_91803_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 68.6%, transparent 68.6%);
# }
# #T_91803_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 95.1%, transparent 95.1%);
# }
# #T_91803_row3_col5, #T_91803_row5_col5 {
#   width: 10em;
# }
# #T_91803_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 88.6%, transparent 88.6%);
# }
# #T_91803_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 44.2%, transparent 44.2%);
# }
# #T_91803_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 49.4%, transparent 49.4%);
# }
# #T_91803_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 62.9%, transparent 62.9%);
# }
# #T_91803_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 67.4%, transparent 67.4%);
# }
# #T_91803_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 93.8%, transparent 93.8%);
# }
# #T_91803_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 36.0%, transparent 36.0%);
# }
# </style>
# <table id="T_91803">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91803_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_91803_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_91803_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_91803_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_91803_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_91803_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_91803_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91803_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_91803_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_91803_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_91803_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_91803_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_91803_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_91803_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_91803_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_91803_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_91803_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_91803_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_91803_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_91803_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_91803_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_91803_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_91803_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_91803_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_91803_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_91803_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_91803_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_91803_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_91803_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_91803_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_91803_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_91803_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_91803_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_91803_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_91803_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_91803_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_91803_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_91803_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_91803_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_91803_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_91803_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_91803_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_91803_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_91803_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_91803_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_91803_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_91803_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_91803_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_91803_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_91803_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_91803_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_91803_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_91803_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_91803_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_91803_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_91803_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_91803_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_91803_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There are other parameters in `bar()` that lets us adjust the display of these bar charts. For example, we can modify its height, width, and alignment, as shown in the code and comments below:

# %%
# Further display adjustments of mini bar charts
df.style.bar(color='lightblue',
             width=75, # Percentage of cell, measured from the left, in which to draw the bars. Ranges from 0 to 100
             height=70, # Percentage height of bar in the cell, centrally aligned. Ranges from 0 to 100
             align='zero' # Defines how to align bars within cells relative to a width adjusted center. Default is 'mid'
            )
# Out:
# <style type="text/css">
# #T_b9b27_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 57.9%, transparent 57.9%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 44.0%, transparent 44.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 55.6%, transparent 55.6%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row0_col5, #T_b9b27_row2_col5, #T_b9b27_row3_col6, #T_b9b27_row5_col6, #T_b9b27_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row0_col6, #T_b9b27_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.5%, transparent 62.5%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 52.8%, transparent 52.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row1_col3, #T_b9b27_row1_col5, #T_b9b27_row2_col2, #T_b9b27_row4_col6, #T_b9b27_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 75.0%, transparent 75.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row1_col6, #T_b9b27_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 56.2%, transparent 56.2%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 58.9%, transparent 58.9%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row2_col3, #T_b9b27_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 40.3%, transparent 40.3%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 43.8%, transparent 43.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.1%, transparent 62.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 63.2%, transparent 63.2%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 73.1%, transparent 73.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row3_col5, #T_b9b27_row5_col5 {
#   width: 10em;
# }
# #T_b9b27_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 70.7%, transparent 70.7%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 54.1%, transparent 54.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 56.0%, transparent 56.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 61.1%, transparent 61.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.8%, transparent 62.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 72.7%, transparent 72.7%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_b9b27_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 51.0%, transparent 51.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# </style>
# <table id="T_b9b27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9b27_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_b9b27_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_b9b27_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_b9b27_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_b9b27_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_b9b27_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_b9b27_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9b27_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b9b27_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_b9b27_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_b9b27_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_b9b27_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_b9b27_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_b9b27_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_b9b27_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b9b27_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b9b27_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_b9b27_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_b9b27_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_b9b27_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_b9b27_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_b9b27_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_b9b27_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b9b27_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b9b27_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_b9b27_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_b9b27_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_b9b27_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_b9b27_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_b9b27_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_b9b27_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b9b27_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b9b27_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_b9b27_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_b9b27_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_b9b27_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_b9b27_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_b9b27_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_b9b27_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b9b27_level0_row4" class="row_heading level0 row4"

# %% [markdown]
# We can see that just these three parameters (`width`, `height`, and `align`) alone can let us make major changes to how these mini charts are displayed. The `align` parameter defines how to align the bars within the cells relative to a width adjusted center, and it takes a range of arguments such as `mid` (default), `zero`, `left`, `right`, and `mean`.
#
# If we wish to provide more granular style adjustments, we can also use the `props` parameter to specify the CSS specification. However, an important thing to take note is that the `props` parameter override the settings defined in the `width` parameter, as seen in the example below. It is because the `props` parameters come with the CSS setting of `width:10em;` by default.

# %%
# Include CSS specifications
df.style.bar(color='lightblue',
             width=75,
             height=70, 
             align='zero',
             props='font-weight:bold;' # Include CSS specification
            )
# Out:
# <style type="text/css">
# #T_d0961_row0_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 57.9%, transparent 57.9%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row0_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 44.0%, transparent 44.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row0_col3 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 55.6%, transparent 55.6%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row0_col5, #T_d0961_row2_col5, #T_d0961_row3_col6, #T_d0961_row5_col6, #T_d0961_row6_col5 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row0_col6, #T_d0961_row4_col5 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.5%, transparent 62.5%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row1_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row1_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 52.8%, transparent 52.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row1_col3, #T_d0961_row1_col5, #T_d0961_row2_col2, #T_d0961_row4_col6, #T_d0961_row6_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 75.0%, transparent 75.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row1_col6, #T_d0961_row6_col6 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 56.2%, transparent 56.2%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row2_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 58.9%, transparent 58.9%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row2_col3, #T_d0961_row6_col3 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 40.3%, transparent 40.3%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row2_col6 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 43.8%, transparent 43.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row3_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.1%, transparent 62.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row3_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 63.2%, transparent 63.2%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row3_col3 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 73.1%, transparent 73.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row3_col5, #T_d0961_row5_col5 {
#   font-weight: bold;
# }
# #T_d0961_row4_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 70.7%, transparent 70.7%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row4_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 54.1%, transparent 54.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row4_col3 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 56.0%, transparent 56.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row5_col1 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 61.1%, transparent 61.1%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row5_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 62.8%, transparent 62.8%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row5_col3 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 72.7%, transparent 72.7%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# #T_d0961_row6_col2 {
#   font-weight: bold;
#   background: linear-gradient(90deg, transparent 37.5%, lightblue 37.5%, lightblue 51.0%, transparent 51.0%) no-repeat center;
#   background-size: 100% 70.0%;
# }
# </style>
# <table id="T_d0961">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0961_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_d0961_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_d0961_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_d0961_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_d0961_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_d0961_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_d0961_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0961_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d0961_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_d0961_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_d0961_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_d0961_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_d0961_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_d0961_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d0961_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d0961_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d0961_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_d0961_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_d0961_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_d0961_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_d0961_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_d0961_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_d0961_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d0961_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d0961_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_d0961_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_d0961_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_d0961_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_d0961_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_d0961_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_d0961_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d0961_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d0961_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_d0961_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_d0961_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_d0961_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_d0961_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_d0961_row3_col5" class="data row3 col5" >0</td>
#       <td id

# %% [markdown]
# > **Note**: The `vmin` and `vmax` parameters seen in `background_gradient` and `text_gradient` are present in `bar()` as well.

# %% [markdown]
# ## Combining styles
# A great thing about styling DataFrames is that we can chain multiple style functions together. The following code is a great example of this, where we incorporate data formatting, mini bar chart generation, and text gradients.

# %%
# Set numerical columns
numerical_cols = ['Age', 'AnnualIncome', 'SpendingScore', 'WorkExperience', 'FamilySize']

# Implement formatting, bar charts, and text gradients
df_nan.style.format(subset=numerical_cols,
                    formatter='{:.3f}', # 3 decimal places
                    na_rep='')\
            .bar(align=0, 
                 cmap="Spectral", 
                 height=50,
                 width=60, 
                 props="width: 120px; border-right: 1px solid black;")\
            .text_gradient(cmap="Set1", vmin=10, vmax=30000)
# Out:
# <style type="text/css">
# #T_45fcc_row0_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #9e0142 30.0%, #9e0142 46.3%, transparent 46.3%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row0_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #9e0142 30.0%, #9e0142 37.6%, transparent 37.6%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #ff7f00;
# }
# #T_45fcc_row0_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #feec9f 30.0%, #feec9f 44.4%, transparent 44.4%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row0_col5, #T_45fcc_row2_col2, #T_45fcc_row5_col5, #T_45fcc_row6_col5 {
#   width: 120px;
#   border-right: 1px solid black;
#   color: #000000;
# }
# #T_45fcc_row0_col6 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #e6f598 30.0%, #e6f598 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row1_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #dd4a4c 30.0%, #dd4a4c 48.0%, transparent 48.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row1_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fff1a8 30.0%, #fff1a8 47.8%, transparent 47.8%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #999999;
# }
# #T_45fcc_row1_col3, #T_45fcc_row1_col5, #T_45fcc_row4_col6, #T_45fcc_row6_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #5e4fa2 30.0%, #5e4fa2 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row1_col6, #T_45fcc_row6_col6 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fee08b 30.0%, #fee08b 45.0%, transparent 45.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row2_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #c1274a 30.0%, #c1274a 47.1%, transparent 47.1%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row2_col3, #T_45fcc_row6_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #9e0142 30.0%, #9e0142 32.2%, transparent 32.2%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row2_col5 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fdbf6f 30.0%, #fdbf6f 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row2_col6 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #9e0142 30.0%, #9e0142 35.0%, transparent 35.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row3_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f98e52 30.0%, #f98e52 49.7%, transparent 49.7%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row3_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #5e4fa2 30.0%, #5e4fa2 60.0%, transparent 60.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #999999;
# }
# #T_45fcc_row3_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #486cb0 30.0%, #486cb0 58.5%, transparent 58.5%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row3_col5 {
#   width: 120px;
#   border-right: 1px solid black;
#   color: #e41a1c;
# }
# #T_45fcc_row3_col6, #T_45fcc_row5_col6 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f46d43 30.0%, #f46d43 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row4_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #86cfa5 30.0%, #86cfa5 56.6%, transparent 56.6%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row4_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fafdb7 30.0%, #fafdb7 49.3%, transparent 49.3%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #999999;
# }
# #T_45fcc_row4_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fff1a8 30.0%, #fff1a8 44.8%, transparent 44.8%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row4_col5 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #bfe5a0 30.0%, #bfe5a0 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row5_col1 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #f06744 30.0%, #f06744 48.9%, transparent 48.9%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row5_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #555aa7 30.0%, #555aa7 59.5%, transparent 59.5%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #999999;
# }
# #T_45fcc_row5_col3 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #4175b4 30.0%, #4175b4 58.1%, transparent 58.1%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #e41a1c;
# }
# #T_45fcc_row6_col2 {
#   width: 120px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 30.0%, #fece7c 30.0%, #fece7c 45.8%, transparent 45.8%) no-repeat center;
#   background-size: 100% 50.0%;
#   color: #999999;
# }
# </style>
# <table id="T_45fcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45fcc_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_45fcc_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_45fcc_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_45fcc_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_45fcc_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_45fcc_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_45fcc_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45fcc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_45fcc_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_45fcc_row0_col1" class="data row0 col1" >19.000</td>
#       <td id="T_45fcc_row0_col2" class="data row0 col2" >15000.000</td>
#       <td id="T_45fcc_row0_col3" class="data row0 col3" >39.000</td>
#       <td id="T_45fcc_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_45fcc_row0_col5" class="data row0 col5" ></td>
#       <td id="T_45fcc_row0_col6" class="data row0 col6" >4.000</td>
#     </tr>
#     <tr>
#       <th id="T_45fcc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_45fcc_row1

# %% [markdown]
# Here is a simpler example if the above one is too complicated:

# %%
# Apply background gradient and highlighting maximum values for every column
df.style.background_gradient(cmap='Blues').highlight_max(color='green')
# Out:
# <style type="text/css">
# #T_6ab7c_row0_col0, #T_6ab7c_row0_col4, #T_6ab7c_row1_col0, #T_6ab7c_row6_col4 {
#   background-color: green;
# }
# #T_6ab7c_row0_col1, #T_6ab7c_row0_col2, #T_6ab7c_row2_col3, #T_6ab7c_row2_col6, #T_6ab7c_row3_col5, #T_6ab7c_row5_col5, #T_6ab7c_row6_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6ab7c_row0_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_6ab7c_row0_col5, #T_6ab7c_row2_col5, #T_6ab7c_row6_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_6ab7c_row0_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_6ab7c_row1_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_6ab7c_row1_col2 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_6ab7c_row1_col3, #T_6ab7c_row1_col5, #T_6ab7c_row2_col2, #T_6ab7c_row4_col6, #T_6ab7c_row6_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   background-color: green;
# }
# #T_6ab7c_row1_col6, #T_6ab7c_row6_col6 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6ab7c_row2_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_6ab7c_row3_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6ab7c_row3_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_6ab7c_row3_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_6ab7c_row3_col6, #T_6ab7c_row5_col6 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6ab7c_row4_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6ab7c_row4_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_6ab7c_row4_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_6ab7c_row4_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_6ab7c_row5_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_6ab7c_row5_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_6ab7c_row5_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_6ab7c_row6_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# </style>
# <table id="T_6ab7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ab7c_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_6ab7c_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_6ab7c_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_6ab7c_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_6ab7c_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_6ab7c_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_6ab7c_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ab7c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6ab7c_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_6ab7c_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_6ab7c_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_6ab7c_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_6ab7c_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_6ab7c_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_6ab7c_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6ab7c_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_6ab7c_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_6ab7c_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_6ab7c_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_6ab7c_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_6ab7c_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_6ab7c_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6ab7c_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_6ab7c_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_6ab7c_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_6ab7c_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_6ab7c_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_6ab7c_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_6ab7c_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6ab7c_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_6ab7c_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_6ab7c_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_6ab7c_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_6ab7c_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_6ab7c_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_6ab7c_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6ab7c_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_6ab7c_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_6ab7c_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_6ab7c_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_6ab7c_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_6ab7c_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_6ab7c_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6ab7c_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_6ab7c_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_6ab7c_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_6ab7c_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_6ab7c_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_6ab7c_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_6ab7c_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6ab7c_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_6ab7c_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_6ab7c_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_6ab7c_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_6ab7c_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_6ab7c_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_6ab7c_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ___
# <a id='section6'></a>
# # (6) Style customization with CSS

# %% [markdown]
# We have already seen snippets of how CSS provides an effective way to control the visual aspects of DataFrames, helping to enhance the understanding and interpretation of data. Let us now delve deeper into how we can implement granular CSS customizations to our DataFrames.
#
# For a start, here is a table containing ten commonly used CSS properties, along with brief descriptions and examples of how to adjust them.

# %% [markdown]
# | Property            | Description                                              | Example usage                   |
# |---------------------|----------------------------------------------------------|---------------------------------|
# | `color`             | Sets the text color                                      | `color: red;`                   |
# | `background-color`  | Sets the background color                                | `background-color: #f0f0f0;`    |
# | `font-size`         | Adjusts the font size                                     | `font-size: 16px;`              |
# | `font-family`       | Specifies the font family                                 | `font-family: 'Arial', sans-serif;` |
# | `margin`            | Sets the margin around elements                           | `margin: 10px 20px;`            |
# | `padding`           | Sets the padding inside elements                          | `padding: 5px 10px;`            |
# | `border`            | Defines the border style, width, and color                 | `border: 2px solid black;`      |
# | `text-align`        | Aligns the text within an element                         | `text-align: center;`           |
# | `width`             | Sets the width of an element                               | `width: 50%;`                   |
# | `height`            | Sets the height of an element                              | `height: 100px;`                |

# %% [markdown]
# There are three primary methods of adding custom CSS styles to `Styler` objects, namely:
# - `set_table_styles()`: Controls broader areas of the table with specified internal CSS
# - `set_td_classes()`: Either directly link external CSS classes to data cells or link internal CSS classes created by the `set_table_styles()` method
# - `apply()` and `applymap()`: Add direct internal CSS to specific data cells
#
# The difference between these customization methods as compared to the conditional formatting techniques is that these CSS customization methods are not dependent on the data in the DataFrame cells. The broader method `set_table_styles()` is  recommended for generic styling (such as entire rows or columns), and are less suitable for individual cell specifications.
#
# Let us look at each one of these three methods in detail.

# %% [markdown]
# ___
# ## (i) Set table styles
#
# The `set_table_styles()` method works by specifying CSS styles within the `<style>` HTML element. It can be used to style the entire table, or specific columns, rows, and HTML selectors. `set_table_styles()` allows us to replicate the normal format of CSS selectors and properties (attribute value pairs). An example of the standard CSS format is shown below:
#
# ```
# #header {
#     font-size: 24px;
# }
# ```
#
# The following code example shows the font size being enlarged and pink background being generated upon hovering our mouse over the DataFrame rows because we have selected the table row hover selector:

# %%
df.style.set_table_styles([{'selector': 'tr:hover', # Set CSS selector
                            'props': 'background-color: pink; font-size: 1.1em;'} # Set CSS properties (attribute value pairs)
                          ])
# Out:
# <style type="text/css">
# #T_d2398 tr:hover {
#   background-color: pink;
#   font-size: 1.1em;
# }
# </style>
# <table id="T_d2398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2398_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_d2398_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_d2398_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_d2398_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_d2398_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_d2398_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_d2398_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2398_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d2398_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_d2398_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_d2398_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_d2398_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_d2398_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_d2398_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d2398_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d2398_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_d2398_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_d2398_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_d2398_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_d2398_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_d2398_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_d2398_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d2398_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_d2398_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_d2398_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_d2398_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_d2398_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_d2398_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_d2398_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d2398_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_d2398_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_d2398_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_d2398_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_d2398_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_d2398_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_d2398_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d2398_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_d2398_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_d2398_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_d2398_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_d2398_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_d2398_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_d2398_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d2398_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_d2398_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_d2398_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_d2398_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_d2398_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_d2398_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_d2398_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d2398_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d2398_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_d2398_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_d2398_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_d2398_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_d2398_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_d2398_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_d2398_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Note**: The CSS properties passed into the `'props'` attribute can either be a list of 2-tuples (e.g., `'props':[('background-color', 'pink')]` or a regular CSS-string (e.g., `'props':'background-color: pink;'`)

# %% [markdown]
# We also can do specific row and column styling. For instance, the example below shows how to apply different CSS styles to two different columns in the DataFrame and with different selectors:

# %%
# Provide different styles for different columns of the table
df.style.set_table_styles({
                        'Gender': [{'selector': '',  # By leaving selector as '', we are selecting the entire column
                                   'props': [('color', 'red')]}], # Set props with list of 2-tuples
                        'Profession': [{'selector': 'td', # Only apply to table cells, and not colum header
                                        'props': 'color: green;'}] # Set props with regular CSS string
                          }, overwrite=False)
# Out:
# <style type="text/css">
# #T_7c2f1 .col0 {
#   color: red;
# }
# #T_7c2f1 td.col4 {
#   color: green;
# }
# </style>
# <table id="T_7c2f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c2f1_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_7c2f1_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_7c2f1_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_7c2f1_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_7c2f1_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_7c2f1_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_7c2f1_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c2f1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7c2f1_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_7c2f1_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_7c2f1_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_7c2f1_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_7c2f1_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_7c2f1_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7c2f1_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7c2f1_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_7c2f1_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_7c2f1_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_7c2f1_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_7c2f1_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_7c2f1_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_7c2f1_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7c2f1_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_7c2f1_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_7c2f1_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_7c2f1_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_7c2f1_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_7c2f1_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_7c2f1_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7c2f1_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_7c2f1_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_7c2f1_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_7c2f1_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_7c2f1_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_7c2f1_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_7c2f1_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7c2f1_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_7c2f1_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_7c2f1_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_7c2f1_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_7c2f1_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_7c2f1_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_7c2f1_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7c2f1_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_7c2f1_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_7c2f1_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_7c2f1_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_7c2f1_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_7c2f1_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_7c2f1_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7c2f1_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7c2f1_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_7c2f1_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_7c2f1_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_7c2f1_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_7c2f1_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_7c2f1_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_7c2f1_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From the output above, we see that by setting `'selector': ''`, the CSS properties will apply to the entire column since no argument is passed. However, if we set `'selector': 'td'`, the style change only applies to the data cells in the column but not the column header. Since we are chaining methods when we specify styles for different parts of the table, we need to explicitly set the `overwrite` parameter to `False` so that existing styles are not overwritten.
#
# Here is an example of a more comprehensive table stylization involving the customization of cell hovers, index names, and column headers:

# %%
# Create dictionaries for each specific CSS selector stylization
cell_hover = {  
    'selector': 'td:hover',  # for row hover use <tr> instead of <td>
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: bold; color: green;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}

# Apply custom styles to DataFrame by passing a list of dictionaries
df.style.set_table_styles([cell_hover, index_names, headers], overwrite=False)
# Out:
# <style type="text/css">
# #T_2714b td:hover {
#   background-color: #ffffb3;
# }
# #T_2714b .index_name {
#   font-style: bold;
#   color: green;
# }
# #T_2714b th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# </style>
# <table id="T_2714b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2714b_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_2714b_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_2714b_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_2714b_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_2714b_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_2714b_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_2714b_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2714b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2714b_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_2714b_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_2714b_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_2714b_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_2714b_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_2714b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_2714b_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2714b_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_2714b_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_2714b_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_2714b_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_2714b_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_2714b_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_2714b_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2714b_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_2714b_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_2714b_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_2714b_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_2714b_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_2714b_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_2714b_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2714b_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_2714b_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_2714b_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_2714b_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_2714b_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_2714b_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_2714b_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2714b_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_2714b_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_2714b_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_2714b_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_2714b_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_2714b_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_2714b_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2714b_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_2714b_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_2714b_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_2714b_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_2714b_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_2714b_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_2714b_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2714b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2714b_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_2714b_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_2714b_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_2714b_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_2714b_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_2714b_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_2714b_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## (ii) Set data cell styles

# %% [markdown]
# The `set_td_classes()` method allows us to apply CSS styles to the <td> elements in a DataFrame when rendering to HTML. This is particularly useful when using custom styling for different table cells. The method takes a DataFrame containing strings that will be translated to CSS classes, mapped by column name and index key values.
#
# In the example below, there are three steps taken:
# 1) Define the desired CSS properties using the `set_table_styles()` method. It is because rather than use external CSS, we will create our classes internally and add them to the table style
# 2) Create a new DataFrame with the same shape as the original DataFrame, matching the indices and columns to apply the respective CSS class property to each cell
# 3) Apply the CSS properties to the original DataFrame using `set_td_classes()`.

# %%
# Create internal CSS classes (3 classes in total) for specific selectors (Store inside variable)
styled_df = df.style.set_table_styles([  
                        {'selector': '.class-a', 'props': 'background-color: red;'},
                        {'selector': '.class-b', 'props': 'background-color: orange;'},
                        {'selector': '.class-c', 'props': 'background-color: green;'}
                        ], overwrite=False)

# %%
# Create DataFrame with the same shape as the original DataFrame (i.e., 7x7) to implement the CSS classes
classes = pd.DataFrame([['class-a']*7, # Create row of 7 red cells
                        ['class-b']*7, # Create row of 7 orange cells
                        ['class-c']*7, # Create row of 7 green cells
                        ['class-a']*7,
                        ['class-b']*7,
                        ['class-c']*7,
                        ['class-a']*7],
                        index=df.index, 
                        columns=df.columns)

# %%
# Apply CSS properties to data cells in DataFrame
styled_df.set_td_classes(classes)
# Out:
# <style type="text/css">
# #T_1b47a .class-a {
#   background-color: red;
# }
# #T_1b47a .class-b {
#   background-color: orange;
# }
# #T_1b47a .class-c {
#   background-color: green;
# }
# </style>
# <table id="T_1b47a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b47a_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_1b47a_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_1b47a_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_1b47a_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_1b47a_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_1b47a_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_1b47a_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b47a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1b47a_row0_col0" class="data row0 col0 class-a" >Male</td>
#       <td id="T_1b47a_row0_col1" class="data row0 col1 class-a" >19</td>
#       <td id="T_1b47a_row0_col2" class="data row0 col2 class-a" >15000</td>
#       <td id="T_1b47a_row0_col3" class="data row0 col3 class-a" >39</td>
#       <td id="T_1b47a_row0_col4" class="data row0 col4 class-a" >Scientist</td>
#       <td id="T_1b47a_row0_col5" class="data row0 col5 class-a" >1</td>
#       <td id="T_1b47a_row0_col6" class="data row0 col6 class-a" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1b47a_row1_col0" class="data row1 col0 class-b" >Male</td>
#       <td id="T_1b47a_row1_col1" class="data row1 col1 class-b" >21</td>
#       <td id="T_1b47a_row1_col2" class="data row1 col2 class-b" >35000</td>
#       <td id="T_1b47a_row1_col3" class="data row1 col3 class-b" >81</td>
#       <td id="T_1b47a_row1_col4" class="data row1 col4 class-b" >Engineer</td>
#       <td id="T_1b47a_row1_col5" class="data row1 col5 class-b" >3</td>
#       <td id="T_1b47a_row1_col6" class="data row1 col6 class-b" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1b47a_row2_col0" class="data row2 col0 class-c" >Female</td>
#       <td id="T_1b47a_row2_col1" class="data row2 col1 class-c" >20</td>
#       <td id="T_1b47a_row2_col2" class="data row2 col2 class-c" >86000</td>
#       <td id="T_1b47a_row2_col3" class="data row2 col3 class-c" >6</td>
#       <td id="T_1b47a_row2_col4" class="data row2 col4 class-c" >Engineer</td>
#       <td id="T_1b47a_row2_col5" class="data row2 col5 class-c" >1</td>
#       <td id="T_1b47a_row2_col6" class="data row2 col6 class-c" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1b47a_row3_col0" class="data row3 col0 class-a" >Female</td>
#       <td id="T_1b47a_row3_col1" class="data row3 col1 class-a" >23</td>
#       <td id="T_1b47a_row3_col2" class="data row3 col2 class-a" >59000</td>
#       <td id="T_1b47a_row3_col3" class="data row3 col3 class-a" >77</td>
#       <td id="T_1b47a_row3_col4" class="data row3 col4 class-a" >Lawyer</td>
#       <td id="T_1b47a_row3_col5" class="data row3 col5 class-a" >0</td>
#       <td id="T_1b47a_row3_col6" class="data row3 col6 class-a" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_1b47a_row4_col0" class="data row4 col0 class-b" >Female</td>
#       <td id="T_1b47a_row4_col1" class="data row4 col1 class-b" >31</td>
#       <td id="T_1b47a_row4_col2" class="data row4 col2 class-b" >38000</td>
#       <td id="T_1b47a_row4_col3" class="data row4 col3 class-b" >40</td>
#       <td id="T_1b47a_row4_col4" class="data row4 col4 class-b" >Artist</td>
#       <td id="T_1b47a_row4_col5" class="data row4 col5 class-b" >2</td>
#       <td id="T_1b47a_row4_col6" class="data row4 col6 class-b" >6</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_1b47a_row5_col0" class="data row5 col0 class-c" >Female</td>
#       <td id="T_1b47a_row5_col1" class="data row5 col1 class-c" >22</td>
#       <td id="T_1b47a_row5_col2" class="data row5 col2 class-c" >58000</td>
#       <td id="T_1b47a_row5_col3" class="data row5 col3 class-c" >76</td>
#       <td id="T_1b47a_row5_col4" class="data row5 col4 class-c" >Engineer</td>
#       <td id="T_1b47a_row5_col5" class="data row5 col5 class-c" >0</td>
#       <td id="T_1b47a_row5_col6" class="data row5 col6 class-c" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1b47a_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_1b47a_row6_col0" class="data row6 col0 class-a" >Female</td>
#       <td id="T_1b47a_row6_col1" class="data row6 col1 class-a" >35</td>
#       <td id="T_1b47a_row6_col2" class="data row6 col2 class-a" >31000</td>
#       <td id="T_1b47a_row6_col3" class="data row6 col3 class-a" >6</td>
#       <td id="T_1b47a_row6_col4" class="data row6 col4 class-a" >Scientist</td>
#       <td id="T_1b47a_row6_col5" class="data row6 col5 class-a" >1</td>
#       <td id="T_1b47a_row6_col6" class="data row6 col6 class-a" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Note**: Because `set_td_classes()` works specifically on the data cells, it does not modify the column header rows or indexes.

# %% [markdown]
# ## (iii) Apply functions

# %% [markdown]
# We can use the apply methods of `apply()` and `applymap()` to take a styling function and apply it to the DataFrame for CSS style rendering. While generally similar, these two methods have some slight differences:
# - `applymap()`: Applies a function that accepts and returns a scalar to every element of a DataFrame. This can be used to style specific cells based on their values.
# - `apply()`: Applies a function along any axis of the DataFrame. This is typically used to style specific rows or columns based on their values rather than individual cells.
#
# Let's look at some examples, starting with the use of `applymap()`. In the following code, we see how we can use `applymap()` to color the font red if the numerical value is less than 3:

# %%
# Define custom styling function to change the cell text color
def color_font_red(val):
    color = 'red' if val < 3 else 'black'
    return f'color: {color}'

# Set numerical columns
numerical_cols = ['Age', 'AnnualIncome', 'SpendingScore', 'WorkExperience', 'FamilySize']

# Use applymap() to apply func to specific cells
df.style.applymap(func=color_font_red,
                  subset=numerical_cols)
# Out:
# <style type="text/css">
# #T_a3da8_row0_col1, #T_a3da8_row0_col2, #T_a3da8_row0_col3, #T_a3da8_row0_col6, #T_a3da8_row1_col1, #T_a3da8_row1_col2, #T_a3da8_row1_col3, #T_a3da8_row1_col5, #T_a3da8_row1_col6, #T_a3da8_row2_col1, #T_a3da8_row2_col2, #T_a3da8_row2_col3, #T_a3da8_row3_col1, #T_a3da8_row3_col2, #T_a3da8_row3_col3, #T_a3da8_row4_col1, #T_a3da8_row4_col2, #T_a3da8_row4_col3, #T_a3da8_row4_col6, #T_a3da8_row5_col1, #T_a3da8_row5_col2, #T_a3da8_row5_col3, #T_a3da8_row6_col1, #T_a3da8_row6_col2, #T_a3da8_row6_col3, #T_a3da8_row6_col6 {
#   color: black;
# }
# #T_a3da8_row0_col5, #T_a3da8_row2_col5, #T_a3da8_row2_col6, #T_a3da8_row3_col5, #T_a3da8_row3_col6, #T_a3da8_row4_col5, #T_a3da8_row5_col5, #T_a3da8_row5_col6, #T_a3da8_row6_col5 {
#   color: red;
# }
# </style>
# <table id="T_a3da8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3da8_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_a3da8_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_a3da8_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_a3da8_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_a3da8_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_a3da8_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_a3da8_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3da8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a3da8_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_a3da8_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_a3da8_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_a3da8_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_a3da8_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_a3da8_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_a3da8_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a3da8_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_a3da8_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_a3da8_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_a3da8_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_a3da8_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_a3da8_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_a3da8_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a3da8_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_a3da8_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_a3da8_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_a3da8_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_a3da8_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_a3da8_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_a3da8_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a3da8_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_a3da8_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_a3da8_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_a3da8_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_a3da8_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_a3da8_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_a3da8_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a3da8_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_a3da8_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_a3da8_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_a3da8_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_a3da8_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_a3da8_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_a3da8_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a3da8_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_a3da8_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_a3da8_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_a3da8_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_a3da8_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_a3da8_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_a3da8_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a3da8_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a3da8_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_a3da8_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_a3da8_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_a3da8_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_a3da8_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_a3da8_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_a3da8_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The output above shows that the specific cells with numbers smaller than 2 (primarily in the "WorkExperience" and "FamilySize" columns) have the text displayed in red font.
#
# The following example shows how we can use `apply()` to highlight the maximum value in each column:

# %%
# Define custom styling function to highlight the max cells in green
def highlight_max_green(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

# Set numerical columns
numerical_cols = ['Age', 'AnnualIncome', 'SpendingScore', 'WorkExperience', 'FamilySize']

# Apply styling function at the column level (axis=0)
df.style.apply(func=highlight_max_green,
               subset=numerical_cols,
               axis=0)
# Out:
# <style type="text/css">
# #T_ad4a3_row1_col3, #T_ad4a3_row1_col5, #T_ad4a3_row2_col2, #T_ad4a3_row4_col6, #T_ad4a3_row6_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_ad4a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad4a3_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_ad4a3_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_ad4a3_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_ad4a3_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_ad4a3_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_ad4a3_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_ad4a3_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad4a3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ad4a3_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_ad4a3_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_ad4a3_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_ad4a3_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_ad4a3_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_ad4a3_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ad4a3_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ad4a3_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_ad4a3_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_ad4a3_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_ad4a3_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_ad4a3_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_ad4a3_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_ad4a3_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ad4a3_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_ad4a3_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_ad4a3_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_ad4a3_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_ad4a3_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_ad4a3_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ad4a3_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ad4a3_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_ad4a3_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_ad4a3_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_ad4a3_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_ad4a3_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_ad4a3_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_ad4a3_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ad4a3_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_ad4a3_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_ad4a3_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_ad4a3_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_ad4a3_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_ad4a3_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_ad4a3_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ad4a3_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_ad4a3_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_ad4a3_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_ad4a3_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_ad4a3_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_ad4a3_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_ad4a3_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ad4a3_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ad4a3_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_ad4a3_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_ad4a3_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_ad4a3_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_ad4a3_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_ad4a3_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_ad4a3_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `apply()` method is highly flexible as we can use the `axis` parameter to determine how the function is to be applied:
# - Column-wise: `axis=0`
# - Row-wise: `axis=1`
# - Entire table at once: `axis=None`
#
# These two methods can be chained together to apply multiple styling rules. For example, we can use `applymap()` to style the cells and then `apply()` to style the rows or columns, as shown below:

# %%
# Chaining multiple styling functions
def color_font_red(val):
    color = 'red' if val < 3 else 'black'
    return f'color: {color}'

def highlight_max_green(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

df.style.applymap(func=color_font_red,
                  subset=numerical_cols)\
        .apply(func=highlight_max_green,
               subset=numerical_cols,
               axis=0)
# Out:
# <style type="text/css">
# #T_f90d7_row0_col1, #T_f90d7_row0_col2, #T_f90d7_row0_col3, #T_f90d7_row0_col6, #T_f90d7_row1_col1, #T_f90d7_row1_col2, #T_f90d7_row1_col6, #T_f90d7_row2_col1, #T_f90d7_row2_col3, #T_f90d7_row3_col1, #T_f90d7_row3_col2, #T_f90d7_row3_col3, #T_f90d7_row4_col1, #T_f90d7_row4_col2, #T_f90d7_row4_col3, #T_f90d7_row5_col1, #T_f90d7_row5_col2, #T_f90d7_row5_col3, #T_f90d7_row6_col2, #T_f90d7_row6_col3, #T_f90d7_row6_col6 {
#   color: black;
# }
# #T_f90d7_row0_col5, #T_f90d7_row2_col5, #T_f90d7_row2_col6, #T_f90d7_row3_col5, #T_f90d7_row3_col6, #T_f90d7_row4_col5, #T_f90d7_row5_col5, #T_f90d7_row5_col6, #T_f90d7_row6_col5 {
#   color: red;
# }
# #T_f90d7_row1_col3, #T_f90d7_row1_col5, #T_f90d7_row2_col2, #T_f90d7_row4_col6, #T_f90d7_row6_col1 {
#   color: black;
#   background-color: green;
# }
# </style>
# <table id="T_f90d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f90d7_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_f90d7_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_f90d7_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_f90d7_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_f90d7_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_f90d7_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_f90d7_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f90d7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f90d7_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_f90d7_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_f90d7_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_f90d7_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_f90d7_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_f90d7_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_f90d7_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f90d7_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_f90d7_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_f90d7_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_f90d7_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_f90d7_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_f90d7_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_f90d7_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f90d7_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_f90d7_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_f90d7_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_f90d7_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_f90d7_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_f90d7_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_f90d7_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f90d7_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_f90d7_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_f90d7_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_f90d7_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_f90d7_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_f90d7_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_f90d7_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f90d7_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_f90d7_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_f90d7_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_f90d7_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_f90d7_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_f90d7_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_f90d7_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f90d7_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_f90d7_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_f90d7_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_f90d7_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_f90d7_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_f90d7_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_f90d7_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f90d7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f90d7_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_f90d7_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_f90d7_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_f90d7_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_f90d7_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_f90d7_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_f90d7_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We may often come across a convenience wrapper method called `set_properties()`. It is actually just a simple wrapper for `applymap()` where the function returns the same properties for all cells. For example, we can use `set_properties()` to easily define a set of CSS properties we want to apply:

# %%
df.style.set_properties(**{'background-color': 'black', # Note the double asterisk (**) at the front 
                           'color': 'pink',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# #T_feb96_row0_col0, #T_feb96_row0_col1, #T_feb96_row0_col2, #T_feb96_row0_col3, #T_feb96_row0_col4, #T_feb96_row0_col5, #T_feb96_row0_col6, #T_feb96_row1_col0, #T_feb96_row1_col1, #T_feb96_row1_col2, #T_feb96_row1_col3, #T_feb96_row1_col4, #T_feb96_row1_col5, #T_feb96_row1_col6, #T_feb96_row2_col0, #T_feb96_row2_col1, #T_feb96_row2_col2, #T_feb96_row2_col3, #T_feb96_row2_col4, #T_feb96_row2_col5, #T_feb96_row2_col6, #T_feb96_row3_col0, #T_feb96_row3_col1, #T_feb96_row3_col2, #T_feb96_row3_col3, #T_feb96_row3_col4, #T_feb96_row3_col5, #T_feb96_row3_col6, #T_feb96_row4_col0, #T_feb96_row4_col1, #T_feb96_row4_col2, #T_feb96_row4_col3, #T_feb96_row4_col4, #T_feb96_row4_col5, #T_feb96_row4_col6, #T_feb96_row5_col0, #T_feb96_row5_col1, #T_feb96_row5_col2, #T_feb96_row5_col3, #T_feb96_row5_col4, #T_feb96_row5_col5, #T_feb96_row5_col6, #T_feb96_row6_col0, #T_feb96_row6_col1, #T_feb96_row6_col2, #T_feb96_row6_col3, #T_feb96_row6_col4, #T_feb96_row6_col5, #T_feb96_row6_col6 {
#   background-color: black;
#   color: pink;
#   border-color: white;
# }
# </style>
# <table id="T_feb96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_feb96_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_feb96_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_feb96_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_feb96_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_feb96_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_feb96_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_feb96_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feb96_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_feb96_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_feb96_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_feb96_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_feb96_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_feb96_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_feb96_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_feb96_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_feb96_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_feb96_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_feb96_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_feb96_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_feb96_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_feb96_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_feb96_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_feb96_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_feb96_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_feb96_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_feb96_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_feb96_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_feb96_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_feb96_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_feb96_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_feb96_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_feb96_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_feb96_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_feb96_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_feb96_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_feb96_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_feb96_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_feb96_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_feb96_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_feb96_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_feb96_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_feb96_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_feb96_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_feb96_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_feb96_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_feb96_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_feb96_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_feb96_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_feb96_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_feb96_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_feb96_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_feb96_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_feb96_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_feb96_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_feb96_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_feb96_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_feb96_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_feb96_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If we want to work directly on column header rows or indexes, we can use the corresponding methods of `apply_index()` and `applymap_index()` instead, as illustrated with the following example:

# %%
# Define custom styling based on text criteria (starts with letter A)
def color_font_pink(text):
    color = 'pink' if text[0] == 'A' else 'black'
    return f'color: {color}'

# Apply styling function on column headers
df.style.applymap_index(func=color_font_pink,
                        axis=1 # Apply on column headers rows (axis=1)
                       )
# Out:
# <style type="text/css">
# #T_85bbf_level0_col0, #T_85bbf_level0_col3, #T_85bbf_level0_col4, #T_85bbf_level0_col5, #T_85bbf_level0_col6 {
#   color: black;
# }
# #T_85bbf_level0_col1, #T_85bbf_level0_col2 {
#   color: pink;
# }
# </style>
# <table id="T_85bbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85bbf_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_85bbf_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_85bbf_level0_col2" class="col_heading level0 col2" >AnnualIncome</th>
#       <th id="T_85bbf_level0_col3" class="col_heading level0 col3" >SpendingScore</th>
#       <th id="T_85bbf_level0_col4" class="col_heading level0 col4" >Profession</th>
#       <th id="T_85bbf_level0_col5" class="col_heading level0 col5" >WorkExperience</th>
#       <th id="T_85bbf_level0_col6" class="col_heading level0 col6" >FamilySize</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85bbf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_85bbf_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_85bbf_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_85bbf_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_85bbf_row0_col3" class="data row0 col3" >39</td>
#       <td id="T_85bbf_row0_col4" class="data row0 col4" >Scientist</td>
#       <td id="T_85bbf_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_85bbf_row0_col6" class="data row0 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_85bbf_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_85bbf_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_85bbf_row1_col2" class="data row1 col2" >35000</td>
#       <td id="T_85bbf_row1_col3" class="data row1 col3" >81</td>
#       <td id="T_85bbf_row1_col4" class="data row1 col4" >Engineer</td>
#       <td id="T_85bbf_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_85bbf_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_85bbf_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_85bbf_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_85bbf_row2_col2" class="data row2 col2" >86000</td>
#       <td id="T_85bbf_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_85bbf_row2_col4" class="data row2 col4" >Engineer</td>
#       <td id="T_85bbf_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_85bbf_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_85bbf_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_85bbf_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_85bbf_row3_col2" class="data row3 col2" >59000</td>
#       <td id="T_85bbf_row3_col3" class="data row3 col3" >77</td>
#       <td id="T_85bbf_row3_col4" class="data row3 col4" >Lawyer</td>
#       <td id="T_85bbf_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_85bbf_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_85bbf_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_85bbf_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_85bbf_row4_col2" class="data row4 col2" >38000</td>
#       <td id="T_85bbf_row4_col3" class="data row4 col3" >40</td>
#       <td id="T_85bbf_row4_col4" class="data row4 col4" >Artist</td>
#       <td id="T_85bbf_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_85bbf_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_85bbf_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_85bbf_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_85bbf_row5_col2" class="data row5 col2" >58000</td>
#       <td id="T_85bbf_row5_col3" class="data row5 col3" >76</td>
#       <td id="T_85bbf_row5_col4" class="data row5 col4" >Engineer</td>
#       <td id="T_85bbf_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_85bbf_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_85bbf_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_85bbf_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_85bbf_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_85bbf_row6_col2" class="data row6 col2" >31000</td>
#       <td id="T_85bbf_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_85bbf_row6_col4" class="data row6 col4" >Scientist</td>
#       <td id="T_85bbf_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_85bbf_row6_col6" class="data row6 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Note**: There are numerous other useful style techniques that are outside the scope of this lesson, such as [tooltips/captions](https://pandas.pydata.org/docs/user_guide/style.html#Tooltips-and-Captions) and [optimization](https://pandas.pydata.org/docs/user_guide/style.html#Optimization).

# %% [markdown]
# ___
# <a id='section7'></a>
# # (7) Export styled tables

# %% [markdown]
# Having done the wonderful work of applying various styling techniques to DataFrames to make them more visually appealing, it is time to learn how to export them. In general, there are four file formats for which we can export our styled DataFrames:
# - HTML: `to_html()`
# - Excel: `to_excel()`
# - LaTeX: `to_latex()`
# - String (and CSV by extension): `to_string()`
#
# We will delve deeper into the Excel format, given how commonly it is used. To write a single `Styler` to an Excel `.xlsx` file, it is only necessary to specify a target file name as shown below:

# %%
# Create basic styled DataFrame
styled_df = df.style.set_properties(**{'background-color': '#FFFFB3'})

# Export directly to Excel file in destination path (with specific sheet name)
styled_df.to_excel('styled_dataframe.xlsx',
                   sheet_name='Table_1')

# %% [markdown]
# Upon opening the Excel sheet, we can see that the styles have been maintained, as seen in the screenshot below:

# %% [markdown]
# ![Image](https://raw.githubusercontent.com/kennethleungty/Educative-Advanced-Pandas/main/images/Chapter%209/styled_dataframe_1.png)

# %% [markdown]
# If we wish to write to more than one sheet in the Excel workbook, we need to specify an ExcelWriter object, as shown below:

# %%
# Generate another sample DataFrame Styler object
styled_df_2 = df.style.set_properties(**{'background-color': 'pink'})

with pd.ExcelWriter('styled_dataframe_2.xlsx') as writer:  
    styled_df.to_excel(writer, sheet_name='Table_1')
    styled_df_2.to_excel(writer, sheet_name='Table_2')

# %% [markdown]
# The screenshot of the output Excel file is shown below:
#
# ![Image](https://raw.githubusercontent.com/kennethleungty/Educative-Advanced-Pandas/main/images/Chapter%209/styled_dataframe_2.png)

# %% [markdown]
# > **Note**: Only the output methods `to_html()`, `to_string()` and `to_latex()` currently work with concatenated `Styler` objects which we create with `concat()`. Other output methods, including `to_excel()`, do not work with concatenated `Stylers`.
